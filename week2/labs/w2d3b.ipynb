# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2025/blob/main/images/warning.png?raw=true)

# %%
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
  # !pip install --force-reinstall git+https://github.com/jamcoders/jamcoders-public-2025.git --quiet
from jamcoders.base_utils import *
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Week 2 Day 3B: Recursion

# %% [markdown]
# ## Question 0: Definitions and Examples
#
# Starting from the basics:

# %% [markdown]
# What is recursion? Answer in words, and give an example (either in words or in code)

# %%
# Answer here!

# %% [markdown]
# What is a base case?

# %%
# Answer here!

# %% [markdown]
# What is a recursive case?

# %%
# Answer here!

# %% [markdown]
# # **Call a TA to confirm the answers before moving forward!**

# %% [markdown]
# ## Question 1: Ping Pong
#
# Bruno and Adriana like playing ping pong together (this may or may not be true). Let's write functions to play ping pong!

# %% [markdown]
# Help Bruno write a function called `ping(n)`:
#   * if `n == 0`, then `return`.
#   * If `n > 0`: `ping(n)` should `print('ping')` then call `pong(n - 1)`.
#   * you haven't written `pong()` yet, but we will write that next!

# %%
def ping(n):
    """
    Args:
        n (int): Number of ping-pong steps to make.

    Returns:
        None
    """
    #Your code here!

# %% [markdown]
# Help Adriana write a function called `pong(n)`:
# * if `n == 0`, then `return`.
# * `pong(n)` should `print('pong')` then call `ping(n - 1)`.
# * you have already written `ping()`!
#
# **If you call both `ping(n)` and `pong(n)`, you will go into an infinite loop. Make sure you are calling `ping(n - 1)` and `pong(n - 1)`. You will also go into an infinite loop if you forget the base case**

# %%
def pong(n):
    """
    Args:
        n (int): Number of ping-pong steps to make.

    Returns:
        None
    """
    #Your code here!

# %% [markdown]
# Try running `ping(5)`. Can you explain what happens and why?

# %%
# run ping(5). What happens, and why?

# %% [markdown]
# What are the base and recursive cases?

# %%
# explain the base and recursive cases in words

# %% [markdown]
# ## Question 2: List slicing and warm up
#
# Some warm up, since the AC is so cold!

# %% [markdown]
# In recursion, we often have to split the inputs into different parts.
#
# For example, sometimes we might break the input in half and call the function on both halves. Sometimes we might break the input to handle the first thing, and then recursively call the function on the rest of the input.
#
# So, we will practice slicing.

# %% [markdown]
# Write a function to return the first element of a list in a new list.

# %%
def first_element(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (object):
        The first element of lst in a new list. If the list is empty, return the empty list.
    """
    # Your code here!

# This tests your solution
assert_equal(got=first_element([50, 10, 3]), want=[50])
assert_equal(got=first_element([2]), want=[2])
assert_equal(got=first_element(["a", "b", "c", "d", "e"]), want=["a"])

# %% [markdown]
# Write a function to return everything except the first element of a list

# %%
def except_first(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (list(object)):
       A copy of lst with the first element removed. If the list has length < 2, return the empty list.
    """
    # Your code here!

# This tests your solution
assert_equal(got=except_first([50, 10, 3]), want=[10, 3])
assert_equal(got=except_first([2]), want=[])
assert_equal(got=except_first(["a", "b", "c", "d", "e"]), want=["b", "c", "d", "e"])

# %% [markdown]
# Write a function to return everything in the first half of the list. If there is an odd number of items in the list, make the first half one less than the second half.
#
# For example, for the list `[1, 2, 3, 4, 5, 6, 7]`, the first half should return `[1, 2, 3]`

# %%
def first_half(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (list(object)):
       A list containing the first half of lst. If the length of lst is an odd number (2k+1),
       the output will contain the first k items in lst.
    """
    # Your code here!

# This tests your solution
assert_equal(got=first_half([50, 10, 3]), want=[50])
assert_equal(got=first_half([2]), want=[])
assert_equal(got=first_half(["a", "b", "c", "d"]), want=["a", "b"])
assert_equal(got=first_half([1, 2, 3, 4, 5, 6, 7]), want=[1, 2, 3])

# %% [markdown]
# Write a function to return everything in the second half of the list. If there is an odd number, make the second half that you return have one more element than the first half.
#
# For example, for the list `[1, 2, 3, 4, 5, 6, 7]`, the second half should return `[4, 5, 6, 7]`

# %%
def second_half(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (list(object)):
       A list containing the second half of lst. If the length of lst is an odd number (2k+1),
       the output will contain the last k+1 items in lst.
    """
    #Your code here!

# This tests your solution
assert_equal(got=second_half([50, 10, 3]), want=[10, 3])
assert_equal(got=second_half([2]), want=[2])
assert_equal(got=second_half(["a", "b", "c", "d"]), want=["c", "d"])
assert_equal(got=second_half([1, 2, 3, 4, 5, 6, 7]), want=[4, 5, 6, 7])

# %% [markdown]
# Let's check if everything works so far!

# %%
# This tests your solution
test_list = [1,2,3,4,5]
assert_equal(got=first_element(test_list), want=[1])
assert_equal(got=except_first(test_list), want=[2,3,4,5])
assert_equal(got=first_half(test_list), want=[1,2])
assert_equal(got=second_half(test_list), want=[3,4,5])

# %% [markdown]
# ## Question 3: Boolean Recursion
#
# Often, we see recursive functions that return `list`s or `int`s or `float`s or `string`s. However, sometimes we see recursions that return `boolean` values!

# %% [markdown]
# In this question, we will **use recursion** to write a function called `is_in(lst, item)` that takes in a list called `lst` and returns `True` if the `item` is in the `lst`, and `False` otherwise.
#
# There are many ways to write this function, but let's do it recursively. For the first base case, what should we return (`True` or `False`) if `lst` is empty?

# %%
# Answer in words, and write the if statement in code

# %% [markdown]
# For the second base case, should we return `True` or `False` if the first element `lst[0] == item`?

# %%
# Answer in words, and write the if statement in code

# %% [markdown]
# For the recursive case, suppose that we know that the first element is not the item. How can we call `is_in(lst, item)` to check the remainder of the list, excluding the first element that we already know is not the item?
#
# In other words, we already know the first element is not the item, or else we would have triggered the second base case. So, we can call `is_in()` using the `lst` without the first element, searching for the same item as before.

# %%
# Answer in words, and write the recursive call is_in() in code

# %% [markdown]
# # **Call a TA to confirm the answers before moving forward!**

# %% [markdown]
# Now we are ready to write the function!
#
# > Note: This question heavily relies on the list slicing from question 1, and you may use your previous functions if you'd like. These functions include: `first_element()`, `except_first()`, `first_half()`, `second_half()`.

# %%
def is_in(lst, item):
    """
    Args:
        lst (list(object)): A list of objects to seach in.
        item (object): An item to search for.

    Returns (bool):
        Whether item is in lst.
    """

    # ===First base case===: the list has length zero so we return False.
    if #FILL ME IN:
        return False

    first_item = #FILL ME IN

    # ===Second base case===: the first thing in the list is the item we are searching for.
    if #FILL ME IN:
        return True

    # Get the rest of the list
    rest_of_list = #FILL ME IN

    # ===Recursive case===: we search for the item in the rest of the list
    return is_in(#FILL ME IN)

# This tests your solution
assert_equal(got=is_in([1, 2, 3], 3), want=True)
assert_equal(got=is_in(['j', 'c', 22], 'c'), want=True)
assert_equal(got=is_in(['r', 2, 'hello'], 'bye'), want=False)

# %% [markdown]
# ## **Challenge $-$ Optional**
#
# The rest of the question is a challenge problem. For the next part of the question, Elijah wants to write `is_in2(lst, item)` that does the same thing as `is_in(lst, item)`, except it follows a different logic:
#   * if the length of the `lst` is `0`, return `False` because `item` is not in an empty list.
#   * if the length of the `lst` is `1` and the element is `item` (In otherwords, `lst[0] == item`), then we have found the element and `return True`.
#   * otherwise:
#     * call `is_in2()` on the first half of `lst`, keep track of the `return` boolean value using a variable.
#     * call `is_in2()` on the second half of `lst`, keep track of the `return` boolean value using a variable.
#     * return `True` if the value is either in the first half of `lst` or the second half of `lst`, and `False` otherwise.

# %% [markdown]
# Explain in words why the logic above makes sense. This is the most important part of the question, so please ask us to explain this recursion to you before you move on if you are not sure!

# %%
# Write your answer in words here!

# %% [markdown]
# In words, what are the base cases and recursive case?

# %%
# Write your answer in words here!

# %% [markdown]
# Now code `is_in2(lst, item)`

# %%
def is_in2(lst, item):
    """
    Args:
        lst (list(object)): A list of objects to seach in.
        item (object): An item to search for.

    Returns (bool):
        Whether item is in lst.
    """
    # Your code here!

    # A summary of the key steps:
    # 1. handle the empty list

    # 2. handle the list with a single element

    # 3. split the list into two halves (we have already handled the case of an empty list)

    # 4. use recursion to return True if the item is either in the left, OR in the right!

# Test your code here!
assert_equal(got=is_in2([1, 2, 3], 3), want=True)
assert_equal(got=is_in2(['j', 'c', 22], 'c'), want=True)
assert_equal(got=is_in2(['r', 2, 'hello'], 'bye'), want=False)

# %% [markdown]
# # **Call a TA to confirm the answers before moving forward!**

# %% [markdown]
# ## Question 4: Repetition
#
# More exercises!

# %% [markdown]
# ### 4.1: `populate_list`
#
# Write a recursive function `populate_list(lst, n)` append to `lst` the first `n` natural numbers in descending order. The logic is:
# * If `n <= 0` then we're done. `return`.
# * Otherwise:
#     * Append `n` to the end of `lst`
#     * Recursively call `populate_list(lst, n-1)`.
#
# For example, `populate_list(lst, 5)` will add the numbers `[5, 4, 3, 2, 1]` to the end of `lst`.

# %% [markdown]
# What is the base case? What is the recursive case?

# %%
# A few words here, be short.

# %% [markdown]
# Write the function below

# %%
def populate_list(lst, n):
    """
    Args
      list (list of int): The list to be populated.
      n (int): The value to be inserted on the list.

    Returns:
      None
    """
    # Your code here

# This tests your solution
lst = []
populate_list(lst, 5)
assert_equal(got=lst, want=[5, 4, 3, 2, 1])
lst = []
populate_list(lst, 0)
assert_equal(got=lst, want=[])

# %% [markdown]
# ### 4.2: `sum_list`
#
# Consider a recursive function called `sum_list(numbers)`.
# * It takes a list of numbers, `numbers`, as input.
# * It returns the sum of the list.
#
# For example:
#
# ```
# sum_list([1, 1, 1]) == 3
# sum_list([1, 2, 3]) == 6
# sum_list([]) == 0
# sum_list([1, -1]) == 0
# ```

# %% [markdown]
# What is the base case? What is the recursive case?

# %%
# A few words here, be short.

# %% [markdown]
# Use your base case and recursive case to write the `sum_list` function.
#
# *Hint: You can use `numbers[1:]` to get a list containing all but the first element in `numbers`.*

# %%
def sum_list(numbers):
    """
    Returns the sum of all the numbers in a list of number

    Args:
        numbers (list(int)): A list of numbers

    Returns (int):
        The sum of the items in the input
    """

    # Check if input matches the base case, and if so, return base case solution
    # YOUR CODE HERE


    # Else, return recursive case solution
    # YOUR CODE HERE


# After you finish, these should all pass
assert_equal(got=sum_list([1, 1, 1]), want=3)
assert_equal(got=sum_list([1, 2, 3]), want=6)
assert_equal(got=sum_list([]), want=0)
assert_equal(got=sum_list([1]), want=1)

# %% [markdown]
# ## Question 5: Palindromes

# %% [markdown]
# A palindrome is a word that looks the same both forward and backwards. For example `racecar` is a palindrome, because if the letters are read right-to-left, we also get the word `racecer`.
#
# You may notice that a palindrome is like an onion. You may think that is because they both stink. But there is yet another similarity: you can peel the palindrome layer by layer.
#
# For example: Suppose you wanted to check if `'racecar'` is a palindrome. You could look at the first and last letter, and if they are the same, recursively check the rest of the string to see if `'aceca'` is a palindrome.  You could keep on peeling away the first and last letters layer by layer until you have a single letter `e`, which is a palindrome.
#
# Just as we have done before, brainstorm the logic of the function below

# %%
# What are the base cases?

# What are the recursive cases?

# Write some tentative logic for how the code will work in words

# %% [markdown]
# Try to code the recursive function `is_palindrome(string)` that returns `True` if `string` is a palindrome, and `False` otherwise. Make sure it works for both even and odd length `string`s.

# %%
def is_palindrome(string):
    """
    Args
      string (str): A string.

    Returns (bool):
      Whether string is a palindrome.
    """
    # Your code here

    # What is the base case?

    # What is the recursive case?

# This tests your solution
assert_equal(got=is_palindrome(""), want=True)
assert_equal(got=is_palindrome("racecar"), want=True)
assert_equal(got=is_palindrome("raccar"), want=True)
assert_equal(got=is_palindrome("madamimadam"), want=True)
assert_equal(got=is_palindrome("eve"), want=True)
assert_equal(got=is_palindrome("racYXYXcar"), want=False)
assert_equal(got=is_palindrome("racXYXYXXzYXYXczar"), want=False)
assert_equal(got=is_palindrome("cabc"), want=False)

# %% [markdown]
# ## Question 6: Challenge!

# %% [markdown]
# Given a number `n`, print all combinations of balanced brackets of length n.
#
# A sequence of bracket is **balanced** if every opening bracket ( has a corresponding closing bracket ) in the correct order.
#
# For example, these bracket sequences are balanced:
#
#
#
# *   `()`
# *   `(())()`
# *   `(()())(())`
#
# And these are not balanced:
#
# *   `)(`
# *   `())`
# *   `((()`

# %% [markdown]
# ### Print all sequences
#
# Begin by first writing a function that prints all bracket sequences of length `n`, balanced or not.

# %%
def all_bracket_sequences(n, partial_sequence):
    """
    Args
      n (int): the number of characters to be added to partial_sequence.
      partial_sequence (str): the bracket sequence so far.
    """
    # What is the base case?
    # The base case is when we want to print the sequence
    if ________:
        print(________)
        return

    # Recursively call all_balanced_sequences to construct the rest of the sequence
    # Fill in the blanks below
    all_bracket_sequences(______, partial_sequence + ______)
    all_bracket_sequences(______, partial_sequence + ______)


# This tests your solution
all_bracket_sequences(3, "")
# Should print, in some order:
# (((
# (()
# ()(
# ())
# )((
# )()
# ))(
# )))

# %% [markdown]
# ### Print only balanced sequences
#
# Now, to print only the **balanced** sequences, we need to keep track of how many brackets we have opened, so we not close more brackets that were open.

# %%
def balanced_bracket_sequences(n, num_open, partial_sequence):
    """
    Args
      n (int): the number of characters to be added to partial_sequence.
      num_open (int): the number of opening brackets that don't have
                        a corresponding closing bracket yet.
      partial_sequence (str): the bracket sequence so far.
    """
    # What is the base case?
    # The base case is when we want to print the sequence.
    if ________:
        # Remember to check the num_open variable as well
        print(________)
        return

    # We can always add an opening bracket. Fill the blanks below to
    # make a recursive call adding an OPENING bracket.
    # Remember to update the num_open variable
    balanced_bracket_sequences(______, ______, partial_sequence + ______)

    # We can only add closing bracket if we have not closed all our opening brackets
    # Check for this condition below using the num_open variable
    # Remember to update the num_open variable
    if ______:
        balanced_bracket_sequences(______, ______, partial_sequence + ______)


# This tests your solution
balanced_bracket_sequences(8, 0, "")
# Should print, in some order:
# (((())))
# ((()()))
# ((())())
# ((()))()
# (()(()))
# (()()())
# (()())()
# (())(())
# (())()()
# ()((()))
# ()(()())
# ()(())()
# ()()(())
# ()()()()
