# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2025/blob/main/images/warning.png?raw=true)

# %%
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !pip install --force-reinstall git+https://github.com/jamcoders/jamcoders-public-2025.git --quiet
from jamcoders.base_utils import *
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Week 2, Day 1, Challenge Problems

# %% [markdown]
# ## Challange 1: Calculator

# %% [markdown]
# ### 1. Basic Calculator
#
# A math exam exam is coming up. You want to prepare, but you misplaced your calculator, and the computer your using only has jupyter notebook available. Normally you could use arithmetic operators, but your input is given as a string (ex. '1+2*8÷2'). Make a calculator capable of completing addition, subtraction, multiplication, and division. **Do not take order of operations into account. Perform functions from left to right.** Also note that there will be no spaces in the input string, and all numbers will be integers.

# %%
def calc1(string):
    """Computes an arithmetic expression in a string, ignoring order of operations

    Arguments: Arithmetic exrpession (string).
    Returns (float): Result of arithmetic expression
    Effects: None
    """
    # YOUR CODE HERE
    op_list = []
    cur_num = 0
    for c in string:
        if c == '+':
            op_list.append(cur_num)
            op_list.append('+')
            cur_num = 0
        elif c == '-':
            op_list.append(cur_num)
            op_list.append('-')
            cur_num = 0
        elif c == '*':
            op_list.append(cur_num)
            op_list.append('*')
            cur_num = 0
        elif c == '÷':
            op_list.append(cur_num)
            op_list.append('÷')
            cur_num = 0
        else:
            cur_num = cur_num * 10 + int(c)
    op_list.append(cur_num)

    answer = op_list[0]
    for i in range(1, len(op_list), 2):
        if op_list[i] == '+':
            answer = answer + op_list[i+1]
        elif op_list[i] == '-':
            answer = answer - op_list[i+1]
        elif op_list[i] == '*':
            answer = answer * op_list[i+1]
        elif op_list[i] == '÷':
            answer = answer / op_list[i+1]
    return answer

# %%
assert_equal(want=36, got=calc1('1+2+3÷2*12'))
assert_equal(want=0, got=calc1('1+2+3÷2*0'))
assert_equal(want=252, got=calc1('100+2+3÷5*12'))
# Out:
# Test case passed.
# Test case passed.
# Test case passed.

# %% [markdown]
# ### 2. Better Calculator
#
# Now complete exercise 3.1 taking into acount the order of operations. Again, you only need to add functionality for addition, subtraction, multiplication, and division. In addition, there will be no spaces in the string, and all numbers will be integers.
#
# _Hint: It may help to write a function that splits the string into number and operator tokens_

# %%
def calc2(string):
    """Computes an arithmetic expression in a string, with order of operations

    Arguments: Arithmetic exrpession (string).
    Returns (float): Result of arithmetic expression
    Effects: None
    """
    # YOUR CODE HERE
    op_list = []
    cur_num = 0
    for c in string:
        if c == '+':
            op_list.append(cur_num)
            op_list.append('+')
            cur_num = 0
        elif c == '-':
            op_list.append(cur_num)
            op_list.append('-')
            cur_num = 0
        elif c == '*':
            op_list.append(cur_num)
            op_list.append('*')
            cur_num = 0
        elif c == '÷':
            op_list.append(cur_num)
            op_list.append('÷')
            cur_num = 0
        else:
            cur_num = cur_num * 10 + int(c)
    op_list.append(cur_num)

    op_list2 = []
    current = op_list[0]
    for i in range(1, len(op_list), 2):
        if op_list[i] == '*':
            current = current * op_list[i+1]
        elif op_list[i] == '÷':
            current = current / op_list[i+1]
        else:
            op_list2.append(current)
            op_list2.append(op_list[i])
            current = op_list[i+1]
    op_list2.append(current)
    op_list = op_list2

    answer = op_list[0]
    for i in range(1, len(op_list), 2):
        if op_list[i] == '+':
            answer = answer + op_list[i+1]
        elif op_list[i] == '-':
            answer = answer - op_list[i+1]
    return answer

# %%
assert_equal(want=21, got=calc2('1+2+3÷2*12'))
assert_equal(want=3, got=calc2('1+2+3÷2*0'))
assert_equal(want=109.2, got=calc2('100+2+3÷5*12'))
# Out:
# Test case passed.
# Test case passed.
# Test case passed.

# %% [markdown]
# ## Challenge 2: Ancient Egyptian multiplication method
# The ancient Egyptians had a method of multiplying integers using only addition, doubling, and halving. Here is how the method works:
#
# 1. Take two numbers to be multiplied and write them down at the top of two columns.
# 2. In the left-hand column repeatedly halve the previous number, discarding any remainders, and write the result below the last in the same column, until you write a value of 1.
# 3. In the right-hand column repeatedly double the previous number and write the result below. stop when you add a result in the same row as where the left hand column shows 1.
# 4. Examine the table produced and discard any row where the value in the left column is even.
# 5. Sum the values in the right-hand column that remain to produce the result of multiplying the original two numbers together
#
# **For example**:   17 × 34
# Halving the first column:<br>
#
# 17 | 34
# --|--
# 8 |
# 4 |
# 2 |
# 1 |
#
# Doubling the second column:
#
# 17 | 34
# -----|-----
# 8 | 68
# 4 | 136
# 2 | 272
# 1 | 544
#
# Strike-out rows whose first cell is even:
#
# 17 | 34
# ---- | -----
# 8|<s>68</s>
# 4|<s>136</s>
# 2|<s>272</s>
# 1|&emsp;544
#
# Sum the remaining numbers in the right-hand column:
#
# 17 | 34
# ---- | ----
# 8 | --
# 4 | ---
# 2 | ---
# 1 | 544
# **Total** | 578
#
# So 17 multiplied by 34, by the Egyptian method is 578.

# %% [markdown]
# ### 4.1
#
# Define a helper function named `is_even` that takes in an integer and returns True if the number is even or False if it's odd.

# %%
def is_even(n):
    """Tests if a number is even

    Arguments: Number (int).
    Returns (bool): True if n is even, False otherwise
    Effects: None
    """
    # YOUR CODE HERE
    return n % 2 == 0

# %%
# Test cases
assert_equal(want=True, got=is_even(2))
assert_equal(want=False, got=is_even(1))
assert_equal(want=False, got=is_even(15))
# Out:
# Test case passed.
# Test case passed.
# Test case passed.

# %% [markdown]
# ### 4.2
#
# Define another helper function named `halve` that takes in an integer and then returns a list with the halved values till it reaches 1. Make sure the list you are returning is sorted from smallest to largest. For example, if you give it the number **17** it should return the list `[17, 8, 4, 2, 1]`, and if you give it the number **105** it should return the list `[105, 52, 26, 13, 6, 3, 1]`.

# %%
def halve(n):
    """Constructs the first column in Egyptian multiplication

    Arguments: First number in product (int).
    Returns (list): List of numbers in the first colum
    Effects: None
    """
    # YOUR CODE HERE
    halves = []
    while n > 0:
        halves.append(n)
        n = n // 2
    return halves

# %%
# Test cases
assert_equal(want=[17, 8, 4, 2, 1], got=halve(17))
assert_equal(want=[105, 52, 26, 13, 6, 3, 1], got=halve(105))
# Out:
# Test case passed.
# Test case passed.

# %% [markdown]
# ### 4.3
#
# Define another helper function named `double_it` that takes in two arguments. The first argument should be the number that is going to be doubled, and the second should number should be the target length of the list to be returned.(If the second number is 5, you will double the starting number 4 times.) Your function should return a list with the doubled values. Make sure the list is sorted from smallest to largest. For example, if you pass **34** and **5** to your function it should return the list `[34, 68, 136, 272, 544]`.

# %%
def double_it(num, n):
    """Constructs the second column in Egyptian multiplication

    Arguments: Second number in product (int).
    Returns (list): List of numbers in the second colum
    Effects: None
    """
    # YOUR CODE HERE
    doubles = []
    for i in range(n):
        doubles.append(num)
        num *= 2
    return doubles

# %%
# Test cases
assert_equal(want=[34, 68, 136, 272, 544], got=double_it(34, 5))
# Out:
# Test case passed.

# %% [markdown]
# ### 4.4
# Define a helper function named `sum` that takes in two lists. The two lists will have equal length. You should loop through each corresponding pair of elements in the two lists, and if the element in the first list is not even, then you should add the corresponding element from the second list to your total. Your function should use the `is_even` function you defined earlier to check if the element in the first list is even or not.
# For example, calling `sum([17, 8, 4, 2, 1], [34, 68, 136, 272, 544])` should return 578.

# %%
def sum(list1, list2):
    """Sums numbers in list2 whose corresponding elements in list1 are not even

    Arguments:
        list1 (list): First column in Egyptian multiplication
        list2 (list): Second column in Egyptian multiplication
    Returns (int): Egyptian product using input lists
    Effects: None
    """
    # YOUR CODE HERE
    return 0

# %%
# Test cases
assert_equal(want=578, got=sum([17, 8, 4, 2, 1], [34, 68, 136, 272, 544]))

# %% [markdown]
# ### 4.5
#
# Finally, define a function named `multiply` that takes in two arguments (the numbers that are going to be multiplied) and returns the result of multiplying the first number by the second number. You should use the `halve` and `double_it` functions inside this function. Then, pass the results returned from the two helper functions to the `sum` function.

# %%
def multiply(a, b):
    """Multiply two ints with Egyptian multiplication

    Arguments:
        a (int): First multiplication operand
        b (int): Second multiplication operand
    Returns (int): Product of a and b
    Effects: None
    """
    # YOUR CODE HERE
    return 0

# %%
# Test cases
assert_equal(want=578, got=multiply(17, 34))
assert_equal(want=225, got=multiply(15, 15))
assert_equal(want=816, got=multiply(24, 34))
