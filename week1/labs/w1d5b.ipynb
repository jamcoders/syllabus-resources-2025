# %% [markdown]
# # Week 1, Day 5, Part B
# ## More functions, modules and imports, and default parameters

# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2023/blob/main/images/warning.png?raw=true)

# %%
# Always run this code.
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !pip install --force-reinstall git+https://github.com/jamcoders/jamcoders-public-2025.git --quiet
from jamcoders.base_utils import *
from jamcoders.week1.lab4a import *

# %% [markdown]
# ## 1. Plotting

# %% [markdown]
# ### 1.0 Setup
# We are going to create a graph that vizualizes how much water you drank this week.
#
# First we have to install the plotting package `matplotlib` (see the documentation here: https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html).

# %%
# !pip install matplotlib

# %% [markdown]
# ### 1.1
# For now we will only use the `pyplot` module (https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html) from `matplotlib`, and give it a shorter name

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.2
# Create the water intake data. Make a list called `water_intake` with how many cups of water you drank each day this week.
#
# Use `random.randrange()` to help you create a random integer with a value between 0 and 10 (including 10).
#
# Hint: `random.randrange(start, stop)` returns a random integer with a value between `start` and `stop`. Also note that the default value for `start`=`0`.

# %%
# Write your code here



# Test your code here - does the print make sense?
print(water_intake)

# %% [markdown]
# ### 1.3
# Write a function plot_water that makes a bar chart using `plt.bar(x_values, y_values)`
#
# - use `plt.bar(x_values, y_values)` to plot the days on the x-axis, and the cups of water on the y-axis
#
# - use `plt.xlabel("X Label Here")` to label the x-axis 'Days of the Week'
#
# - use `plt.ylabel("Label Here")` to label the y-axis 'Cups of Water'
#
# - use `plt.title("Title Here")` to label the title 'My Water Intake This Week'
#
# - don’t forget `plt.show()`!

# %%
def plot_water(water_list):
    days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    # Write your code here


# Test your code here
plot_water(water_intake)

# %% [markdown]
# ## Check your plot with a TA!!

# %% [markdown]
# ## Congratulations!!!!! You've finished the notebook for today! 🎊🎊
# ## The rest of the challenges below are completely optional. Try finishing all previous notebooks (2a, 2b, 3a...) before attempting the rest of this notebook.

# %% [markdown]
# ### 1.4
# Modify plot_water so it takes a color parameter that defaults to `skyblue`. Use it to color the bars.

# %%
def plot_water(water_list, color='skyblue'):
    days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    # Write your code here


# Test your code here
plot_water(water_intake)
plot_water(water_intake, color='orchid')

# %% [markdown]
# ## Check your plots with a TA!!

# %% [markdown]
# ### 1.5
# Here are some more unique colors and different formats to assign them.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Try plotting your water intake with **at least two new colors**.
#
#
# Challenge: Can you use two *different* formats to assign the same color?
# Feel free to visit this page to read more about colors and how to format them: https://matplotlib.org/stable/users/explain/colors/colors.html

# %%
# Write your code here

# %% [markdown]
# ### 1.6 Challenge
# Update your function to assign a different color to each bar based on the number of cups:
#
# - < 3 → `red`
#
# - 3–5 → `orange`
#
# - 6+ → `green`
#
# You’ll need to:
#
# - Create a list of 7 colors by looping through `water_list` and using `.append(...)`
#
# - Pass that list to the color argument in `plt.bar(...)`
#
# Extra Challenge:
#
# - Add a horizontal line on the plot to mark 6 cups
#
# - Hint: look at what other functions are available to you through `matplotlib.pyplot` (https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html)
#
# - Hint #2: try using `CTRL` + `F` to search through long documentation!!!!

# %%
def plot_water(water_list):
    days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    # Write your code here



# Test your code here
plot_water(water_intake)

# %% [markdown]
# ## Check your plots with a TA!!

# %% [markdown]
# ## 2. My Alphabet
# _Run all the following cells in order._

# %% [markdown]
# ### 2.1
# Create a list called `vowels` that contains all the vowels from the English alphabet in lower case excluding `y`.

# %%
# Write your code here

# %% [markdown]
# ### 2.2
# Create a variable called `my_letter` that has the value `"a"`.

# %%
# Write your code here

# %% [markdown]
# ### 2.3
# Now, write a conditional statement that prints `'True'` when `my_letter` is equal to `"a"`.

# %%
# Write your code here

# %% [markdown]
# ### 2.4
# Write a function called `get_vowels` that iterates through `vowels` and prints each element.

# %%
def get_vowels(lst):
    # Write your code here


# Test your code here
get_vowels(vowels)

# %% [markdown]
# ### 2.5
# Write a function called `is_vowel` that takes in a string called `letter` and returns `True` if `letter` is a vowel and `False` otherwise. **Do this by looping through `vowels` with a `for` loop.**

# %%
def is_vowel(letter):
    # Write your code here


# Test your code here
assert_equal(got=is_vowel('a'), want=True)
assert_equal(got=is_vowel('b'), want=False)

# %% [markdown]
# ### 2.6
# Write a function `is_vowel2` that does the same thing as 3.5, but **using only conditional statements or boolean expressions**.

# %%
def is_vowel2(letter):
    # Write your code here


# Test your code here
assert_equal(got=is_vowel2('a'), want=True)
assert_equal(got=is_vowel2('b'), want=False)

# %% [markdown]
# ### 2.7
# Create a function called `is_consonant`, that returns `True` if the input is **not** a vowel, and `False` otherwise.

# %%
def is_consonant(letter):
    # Write your code here


# Test your code here
assert_equal(got=is_consonant('a'), want=False)
assert_equal(got=is_consonant('l'), want=True)
assert_equal(got=is_consonant('o'), want=False)
assert_equal(got=is_consonant('k'), want=True)

# %% [markdown]
# ### 2.8
# Try running the code below. Does it do what you expect?

# %%
print(is_consonant("a"))
print(is_consonant("b"))
print(is_consonant("1"))
print(is_consonant("."))

# %% [markdown]
# ### 2.9
# Rewrite `is_consonant` so that it also returns `False` when it is not part of the alphabet.

# %%
# Useful functions and variables for you to use:
alphabet = "abcdefghijklmnopqrstuvwxyz"

def is_consonant(letter):
    # Write your code here



# Test your code here
assert_equal(got=is_consonant('a'), want=False)
assert_equal(got=is_consonant('b'), want=True)
assert_equal(got=is_consonant('1'), want=False)
assert_equal(got=is_consonant('.'), want=False)

# Extra challenge: can you edit your code so it works on upper and lower case text?

# %% [markdown]
# ## 3. DN that A!

# %% [markdown]
# ### 3.1
# DNA has 4 bases: Adenine (A), Thymine (T), Cytosine (C), and Guanine (G). Each base fits like a puzzle piece with one other base. Adenine pairs up with Thymine (AT base pairing) and Cytosine pairs up with Guanine (CG base pairing). This is important because DNA is double stranded. Each DNA strand is made up of multiple bases and fits with its other strand using the puzzle piece pairing rules. If we know the bases that make up one strand of DNA, we can figure out which bases make up the other strand by finding each base's complement (the other piece of the puzzle pair). For example:
#
# - `ATACGTACGATCA`  - This is the strand we know.
# - `TATGCATGCTAGT`  - This is the _complement strand_ that we can figure out.
#
#
# As a small exercise, try to figure out the complement strand to the below known strands manually (without code).

# %% [markdown]
# ### 3.1.1 ATCCGGGATCAA
# Store your answer as a string in a variable called `complement1`.

# %%
# Write your code here

# %% [markdown]
# ### 3.1.2 GGCCCCATTTTC
# Store your answer as a string in a variable called `complement2`.

# %%
# Write your code here

# %% [markdown]
# ### 3.2
# Create a variable called `dna` containing the following strand of bases: `'ACTATGGCCGT'`.

# %%
# Write your code here

# %% [markdown]
# ### 3.3
# Write a function called `contains_a(strand)` that returns `True` if `strand` contains an Adenine, expressed as an `'A'`. The function returns `False` otherwise.

# %%
def contains_a(strand):
    # Write your code here


# Test your code here
assert_equal(got=contains_a(dna), want=True)
assert_equal(got=contains_a('TGGCT'), want=False)

# %% [markdown]
# ### 3.4
# Write a function called `complement_base` that takes a given base (i.e. A, C, T, or G) and returns its complement.

# %%
def complement_base(base):
    # Write your code here



# Test your code here
assert_equal(got=complement_base('G'), want='C')
assert_equal(got=complement_base('T'), want='A')
assert_equal(got=complement_base('A'), want='T')
assert_equal(got=complement_base('C'), want='G')

# %% [markdown]
# ### 3.5
# Given a string `str` that contains only A, C, G, and T characters, write a function called `complement_strand` that will return the complement DNA strand explained in 5.1.

# %%
def complement_strand(strand):
    # Write your code here



# Test your code here
assert_equal(got=complement_strand('GATTACA'), want='CTAATGT')

# %% [markdown]
# ## 4. Parish Search Game

# %% [markdown]
# People have already made a lot of really cool open source modules that are available for you to experiment with. You do not need to code anything for this question, just play the game!
#
#
# Here is a game that we made using less than 60 lines of code, thanks to open source modules like `matplotlib.pyplot`, `geopandas`, and `random`.
#
# ### Make sure to type out "saint" if that is in the parish name
# ### example: 'saint james' instead of 'st. james'

# %%
play_parish_search()

# %% [markdown]
# We have implemented a default parameter `tries=3` that lets players have 3 guesses. Feel free to change this number to 1 or 2 guesses if you are confident in your geography skills!

# %%
play_parish_search(tries=1)

# %% [markdown]
# # You're doing awesome! :)
