# %% [markdown]
# # ==== Lecture 1B ====
#
# Content by Alex Krentsel, based off of Daniel Kang's 2023 AddisCoder material.
#
# See [associated slides here](https://docs.google.com/presentation/d/1BGRZBNkfKZFJoarjB9QCao996MFEd-m4Z1SK8odTQb4/).
#
#
# How was lab? Was anything confusing?

# %% [markdown]
# # Review
#
# We covered:
# - Jupyter as a powerful calculator
# - Operations: addition, subtraction, multiplication, division (two types of division!)
# - Special operations: exponentiation, modulus
# - Errors
# - Variables

# %%
print((888 - 88) / 8)
# Out:
# 100.0

# %% [markdown]
# **Reminder: if you're confused, you can test in Jupyter!**

# %%
# Things that were confusing from earlier today


)
# Out:
# 5 6

# %% [markdown]
# ## Extra things
#
# printing, cell ordering (overwriting values in subsequent cells)

# %% [markdown]
# # Types
#
# We will start by learning 4 types.
#
# 1. Bool
# 1. Integer
# 1. Float
# 1. String
#
# There are more types, we will get to them later in the week.

# %%
# booleans

# %% [markdown]
# ### Think Pair Share: Boolean Logic Puzzle 🧩
# **Concepts**: Boolean operators (and, or, not), expressions
#
# What will this expression evaluate to?
#
# ```python
# has_homework = True
# is_weekend = False
# is_tired = True
#
# can_relax = not has_homework or (is_weekend and not is_tired)
# print(can_relax)
# ```
#
# **Think**: Work through the boolean logic step by step.
# **Discuss**: How do `and`, `or`, and `not` combine? What's the order of operations?

# %% [markdown]
# # Casting: converting across Types
#
# We know how to find out the type (`type()`). How do we change the type? Casting!

# %% [markdown]
# ### Checking the Type

# %% [markdown]
# ### Converting between types
#
# You can convert between types using `int`, `float`, `str`, and `bool`

# %% [markdown]
# # Equalities and Inequalities
#
# We can check equality between expressions of the same type. We can also do in-equality checks.

# %% [markdown]
# You can also compare things like strings and booleans. Explore what happens in lab!
#
# # Arithmetic for non-number types
#
# Python also allows for arithmetic operations for non-number types. This can be very confusing, so let's walk through it slowly.

# %% [markdown]
# ## Taking Input
#
# We saw this morning how to print things out. How about how to take them in?

# %% [markdown]
# ### Think, Pair, Share: User Input Trap 🪤
# **Concepts**: User input, casting, arithmetic operators
#
# A student wrote this code to double a number entered by the user:
#
# ```python
# user_number = input("Enter a number: ")
# doubled = user_number * 2
# print("Double your number is:", doubled)
# ```
#
# If the user types `5`, what will be printed?
#
# **Think**: What data type does `input()` always return?
# **Discuss**: How would you fix this code to work as intended?

# %% [markdown]
# ### Think Pair Share: Data Type Detective 🕵️
# **Concepts**: Data types, comparison operators, common mistakes
#
# What will this code print? Think carefully about data types!
#
# ```python
# age1 = "25"
# age2 = 30
# result = age1 > age2
# print(result)
# print(type(result))
# ```
#
# **Think**: What happens when you compare a string to an integer?
# **Discuss**: Why might this cause an error or unexpected behavior? How do we fix it?

# %% [markdown]
# ### Think Pair Share: String Expression Challenge 🎯
# **Concepts**: String operations, expressions, len() function, casting
#
# Predict what this code will print:
#
# ```python
# word = "Python"
# number = 2024
# result = word + " " + str(number)
# print(result)
# print(len(result))
# print(result * 2 == result + result)
# ```
#
# **Think**: Trace through each line carefully. What does each operation do?
# **Discuss**:
# - What's the difference between `+` with strings vs numbers?
# - Why do we need `str(number)`?
# - Will the final comparison be `True` or `False`?
