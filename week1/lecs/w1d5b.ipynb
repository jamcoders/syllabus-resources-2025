# %% [markdown]
# # ==== Lecture 5B ====
#
# Content by Alex Krentsel.
#
# See [associated slides here](https://docs.google.com/presentation/d/17pwDjv5KlYiYJgCjzwdR3yrC1ThPgJzNTR9asVNi1p8/edit?usp=sharing).
#
# My last lecture...
#
# How was lab? Was anything confusing?

# %%
# what to do
# 1. pyramid
# 2. nested lists
# 3. rectangle
# 4. moving arrow
# 5. for loop over strings to while loop over strings

# %% [markdown]
# ```python
# size_of_pyramid = 4
#
# ___x    # x: 1, _:3   == 4
# __x_x   # x: 2, _:2   == 4
# _x_x_x  # x: 3, _:1   == 4
# x_x_x_x # x: 4, _:0   == 4
# ```
#
#
# I know x, and I know size_of_pyramid.
#
# How do I solve for _?
#
# x + _ = size_of_pyramid
#
# _ = size_of_pyramid - x

# %%
size_of_pyramid = 4

for num in range(1, size_of_pyramid + 1):
  prefix_string = " " * (size_of_pyramid - num)
  core_pyramid = "# " * num
  print(prefix_string + core_pyramid)
# Out:
#    #
#   # #
#  # # #
# # # # #

# %%
# Make a function that takes a pyramid size and prints that pyramid

def print_pyramid(size):
  print("I'm about to print a pyramid of size: " + str(size))
  for num in range(1, size + 1):
    prefix_string = " " * (size - num)
    core_pyramid = "# " * num
    print(prefix_string + core_pyramid)

# %%
print_pyramid(-1)
# Out:
# I'm about to print a pyramid of size: -1

# %%
def mystery1(n):
  for i in range(n):
    if i == 4:
      return i
    print(i)

# %%
result = mystery1(8)
print(result)
print("")
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mystery1(3)
# Out:
# 0
# 1
# 2

# %%
2+2
1 + 1
3+3
# Out:
# 6

# %%
# for loop over strings to while loop over strings

# %%
start = 0
stop = 5
for i in range(start, stop):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
index = 0
while index < 5:
  print(index)
  index = index + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
my_tas = ["Piyush", "Bruno", "Joy", "Hanna", "Lydia", "Xavier", "Frank"]

# for item in my_tas:
#   print(item)

start = 0
stop = len(my_tas)
step_size = 1
for index in range(len(my_tas)):
  print(my_tas[index])
# Out:
# Piyush
# Bruno
# Joy
# Hanna
# Lydia
# Xavier
# Frank

# %%
index = 0
while index < len(my_tas):
  item = my_tas[index]
  print(item)
  index = index + 1
# Out:
# Piyush
# Bruno
# Joy
# Hanna
# Lydia
# Xavier
# Frank
