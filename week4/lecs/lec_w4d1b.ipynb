# %%
# %config InteractiveShell.ast_node_interactivity = "none"

# %% [markdown]
# # Digital Skittles

# %% [markdown]
# What if we want to run our experiment on a thousand Skittles?

# %% [markdown]
# - That would be expensive 💸

# %% [markdown]
# - But would make our dentist very happy 😬

# %% [markdown]
# We can run our experiment on the computer!

# %% [markdown]
# First, we need to to tell the computer about our cup:

# %%
cup = ["red", "red", "red", "blue", "yellow", "green"]

# %% [markdown]
# Next, let's sample from it.
# - How can we do something random on the computer?

# %% [markdown]
# - We can `import` it!

# %%
from jamcoders.random import sample_from_list

# %%
print(sample_from_list(cup)) # Sample from the cup
# Out:
# red

# %% [markdown]
# ## Skittle-up 📈

# %% [markdown]
# Let's make a cup with hundredsssss of Skittles...

# %% [markdown]
# - How many reds?
# - How many blues?
# - How many greens?

# %%
cup = ["red"] * 40
cup += ["blue"] * 100
cup += ["yellow"] * 69

# %%
print("Our cup has", len(cup), "Skittles")
# Out:
# Our cup has 209 Skittles

# %%
print(cup)
# Out:
# ['red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow']

# %% [markdown]
# ### Running the experiment

# %% [markdown]
# Just like with our physical cups, we'll:
# - Sample many times from our digital cup
# - Try different sample sizes to see how our estimates improve

# %%
from jamcoders.random import visualize

# %% [markdown]
# The `visualize` function will show us:
# - What's in our cup 🥤 (True distribution)
# - What we saw when sampling (Sampled distribution)
#
# The sampled distributions get closer to the true distribution as we take more samples

# %%
sample_sizes = [50, 200, 1000, 5000]
visualize(cup, sample_sizes)
